# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import sklearn as skl
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.random.randint(0,10,10)
y = np.random.randint(0,10,10)

A = np.vstack([x, np.ones(len(x))]).T
m,c = np.linalg.lstsq(A, y, rcond=None)[0]

plt.figure(figsize=(10,10))
plt.plot(x,y, 'o', label = 'Исходные данные',markersize = 10)
plt.plot(x, m*x+c, 'r', label='Линейная экстраполоция')
plt.legend()
plt.show()

# %%
d = 1.0
x = np.linspace(-5,5,9)
y = x**2 + d*(np.random.rand(9))
x += d*(np.random.rand(9))
#print(x)
#print(y)
m = np.vstack([x**2,x,np.ones(9)]).T
s = np.linalg.lstsq(m, y, rcond = None)[0]
x_prec = np.linspace(-5,5, 100)
plt.plot(x, y, 'o', label = 'Исходные данные')
plt.plot(x_prec, s[0]*x_prec**2 + s[1]*x_prec + s[2],'r', label = 'Линейная экстраполяция')
plt.legend()
plt.grid()
plt.show()

# %%
d = 1.0
x = np.linspace(-5,5,21)
y = x**3 + x**2 + d*(np.random.rand(21))
x += d*(np.random.rand(21))
#print(x)
#print(y)
m = np.vstack([x**3,x**2,x,np.ones(21)]).T
s = np.linalg.lstsq(m, y, rcond = None)[0]
x_prec = np.linspace(-5,5, 100)
plt.plot(x, y, 'o', label = 'Исходные данные')
plt.plot(x_prec, s[0]*x_prec**3 + s[1]*x_prec**2 + s[2]*x_prec + s[3],'r',label = 'Линейная экстраполяция')
plt.legend()
plt.grid()
plt.show()

# %%
b = np.random.random(2) # Шум
def f(x,b0,b1):
    return b0 + b1 * x
xdata = np.linspace(0,5,50)
y = f(xdata, *b)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt,beta_cov = curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = (sum(beta_cov[0]))
print(f'Линейное отклонение: {lin_dev}')

residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals ** 2)
print(f'Квадратичное отклонение: {fres}')

fig,ax = plt.subplots()
fig.suptitle("$b_0 +b_1 x$", fontsize = 18)
ax.scatter(xdata,ydata)
ax.plot(xdata, y, 'r', lw = 2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x,b)$', fontsize=18)
plt.show()
# Out:
# [0.67618818 0.54913711]
# Линейное отклонение: 0.00014082312006486608
# Квадратичное отклонение: 0.12382722323791022

# %%
b = np.random.random(3) # Шум
def f(x,b0,b1,b2):
    return b0 + b1 * x + b2 * x ** 2
xdata = np.linspace(0,5,50)
y = f(xdata, *b)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt,beta_cov = curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = (sum(beta_cov[0]))
print(f'Линейное отклонение: {lin_dev}')

residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals ** 2)
print(f'Квадратичное отклонение: {fres}')

fig,ax = plt.subplots()
fig.suptitle("$b_0 +b_1 + b_2 x^2$", fontsize = 18)
ax.scatter(xdata,ydata)
ax.plot(xdata, y, 'r', lw = 2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x,b)$', fontsize=18)
plt.show()
# Out:
# [0.41934866 0.12904472 0.20209857]
# Линейное отклонение: 0.00015506535328142383
# Квадратичное отклонение: 0.12930826694998634

# %%
b = np.random.random(2) # Шум
def f(x,b0,b1):
    return b0 + b1 * np.log(x)
xdata = np.linspace(1,5,50)
y = f(xdata, *b)
ydata = y + 0.05 * np.random.randn(len(xdata))
beta_opt,beta_cov = curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = (sum(beta_cov[0]))
print(f'Линейное отклонение: {lin_dev}')

residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals ** 2)
print(f'Квадратичное отклонение: {fres}')

fig,ax = plt.subplots()
fig.suptitle("$b_0 +b_1 ln(x)$ ", fontsize = 18)
ax.scatter(xdata,ydata)
ax.plot(xdata, y, 'r', lw = 2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x,b)$', fontsize=18)
plt.show()
# Out:
# [0.26601464 0.36953017]
# Линейное отклонение: 4.742398186299802e-05
# Квадратичное отклонение: 0.10966517871705528

# %%
#4
b = np.random.randint(1,5,size=2) # Шум
def f(x,b0,b1):
    return b0 * x ** b1
xdata = np.linspace(1,5,50)
y = f(xdata, *b)
ydata = y + 0.15 * np.random.randn(len(xdata))
beta_opt,beta_cov = curve_fit(f, xdata, ydata)
print(beta_opt)
lin_dev = (sum(beta_cov[0]))
print(f'Линейное отклонение: {lin_dev}')

residuals = ydata - f(xdata, *beta_opt)
fres = sum(residuals ** 2)
print(f'Квадратичное отклонение: {fres}')

fig,ax = plt.subplots()
fig.suptitle("$b_0 x^{b_1}$", fontsize = 18)
ax.scatter(xdata,ydata)
ax.plot(xdata, y, 'r', lw = 2)
ax.plot(xdata, f(xdata, *beta_opt), 'b', lw = 2)
ax.set_xlim(0,5)
ax.set_xlabel(r'$x$', fontsize=18)
ax.set_ylabel(r'$f(x,b)$', fontsize=18)
plt.show()
# Out:
# [2.98837945 1.00250303]
# Линейное отклонение: 0.0006198148306554871
# Квадратичное отклонение: 1.0654501355567285

# %%
url = 'https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linear-regression/master/Salary_Data.csv'

dataframe = pd.read_csv(url)
#dataframe.head(10)
X = dataframe.iloc[:, :-1].values
Y = dataframe.iloc[:, 1].values
#print(X,Y, sep = '\n')

X_train, X_test, Y_train, Y_test = skl.model_selection.train_test_split(X, Y, test_size=0.15, random_state=0)
regressor = skl.linear_model.LinearRegression()
regressor.fit(X_train,Y_train)
print(regressor.intercept_, regressor.coef_, sep='\n') # Свободный член - значеие Y если X = 0 и Коэффициент наклона - $Y(X+1)$ |Y=intercept + coef*X
y_pred = regressor.predict(X_test)

df = pd.DataFrame({'Actual':Y_test, 'Predicted':y_pred})
df.head(10)
# Out:
# 26673.636747785356
# [9345.57326138]
#      Actual      Predicted
# 0   37731.0   40691.996640
# 1  122391.0  122933.041340
# 2   57081.0   64990.487119
# 3   63218.0   63121.372467
# 4  116969.0  115456.582731

# %%
df.plot(kind='bar')
plt.grid(which='major',linestyle='-', linewidth='0.5',color ='green')
plt.grid(which='minor',linestyle=':', linewidth='0.5',color ='black')
plt.show()
plt.scatter(X_test,Y_test,color='gray')
plt.plot(X_test,y_pred,color='red',linewidth=2)
plt.show()

# %%
import seaborn as sns
url = 'https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv'
petrol_data = pd.read_csv(url)
#petrol_data.head(10)

X = petrol_data.drop(columns=['Petrol_Consumption'])
Y = petrol_data['Petrol_Consumption']

x_train, x_test, y_train, y_test = skl.model_selection.train_test_split(X, Y, test_size= 0.2, random_state= 42)

regressor = skl.linear_model.LinearRegression()
regressor.fit(x_train,y_train)

coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['Coefficient'])

y_pred = regressor.predict(x_test)
df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
display(coeff_df)
df['diff'] = abs(df['Actual'] - df['Predicted'])
display(df)
df.plot(kind='bar')
plt.grid(which='major',linestyle='-', linewidth='0.5',color ='green')
plt.grid(which='minor',linestyle=':', linewidth='0.5',color ='black')
plt.show()
print(f'Mean Squared Error: {skl.metrics.mean_squared_error(y_test,y_pred)}')
# Out:
#                               Coefficient
# Petrol_tax                     -36.993746
# Average_income                  -0.056536
# Paved_Highways                  -0.004382
# Population_Driver_licence(%)  1346.869298
#     Actual   Predicted        diff
# 27     631  606.692665   24.307335
# 40     587  673.779442   86.779442
# 26     577  584.991490    7.991490
# 43     591  563.536910   27.463090
# 24     460  519.058672   59.058672
# 37     704  643.461003   60.538997
# 12     525  572.897614   47.897614
# 19     640  687.077036   47.077036
# 4      410  547.609366  137.609366
# 25     566  530.037630   35.962370
# Mean Squared Error: 4083.255871745411
